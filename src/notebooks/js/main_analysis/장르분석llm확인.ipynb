# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import warnings
from scipy.stats import kruskal
import re

warnings.filterwarnings('ignore')

#plt.rcParams['font.family'] = 'AppleGothic'    # Mac
plt.rcParams['font.family'] = 'Malgun Gothic' # Windows
plt.rcParams['axes.unicode_minus'] = False

print("라이브러리 로드 완료")
# Out:
# 라이브러리 로드 완료

# %%
df = pd.read_csv("../../../../data/preprocessed/tableau_genre_long.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20355 entries, 0 to 20354
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     20355 non-null  int64
#  1   name                      20355 non-null  str
#  2   genre                     20355 non-null  str
#  3   price                     20355 non-null  float64
#  4   positive                  20355 non-null  int64
#  5   negative                  20355 non-null  int64
#  6   total_reviews             20355 non-null  int64
#  7   positive_rate             20355 non-null  float64
#  8   scale_grade               20355 non-null  str
#  9   scale_grade_label         20355 non-null  str
#  10  satisfaction_grade        20355 non-null  str
#  11  satisfaction_grade_label  20355 non-null  str
#  12  performance_grade         20355 non-null  str
#  13  performance_grade_label   0 non-null      float64
#  14  tags                      20355 non-null  str
# dtypes: float64(3), int64(4), str(8)
# memory usage: 2.3 MB

# %%
df['appid'].nunique()
# Out:
# 9314
