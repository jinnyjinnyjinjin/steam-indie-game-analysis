# %% [markdown]
# # Steam 인디게임 초기 반응 분석
#
# ## 분석 목적
# - 출시 후 30일 기준 초기 리뷰 반응 규모 확인
# - 초기 긍정률 및 Wilson score 기반 품질 지표 생성
# - 초기 반응이 이후 리뷰 유입으로 이어지는지 확인
# - 게임별 반응 유형 분류
# - 최종 분석용 CSV 저장

# %% [markdown]
# # 0. 라이브러리 호출

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import spearmanr, mannwhitneyu, kruskal
from IPython.display import display
from pathlib import Path

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# 한글 폰트 설정
import platform
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
elif platform.system() == 'Darwin':  # macOS
    plt.rcParams[
        'font.family'] = 'AppleGothic'
else:  # Linux
    plt.rcParams['font.family'] = 'NanumGothic'

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # 1. 데이터 호출

# %%
# 프로젝트 루트 직접 지정
# 다른 환경에서 실행할 경우 ROOT만 본인 프로젝트 경로에 맞게 수정합니다.
ROOT = Path(r"C:\Users\joon5\Documents\github\steam-indie-game-analysis")

# 원천/소스 파일이 들어있는 폴더
print("호출 폴더")
DATA_DIR = ROOT / "data" / "processed"
FULL_PATH = DATA_DIR / "steam_indie_review_histogram_preprocessed_lee_v2.csv"

print("DATA_DIR:", DATA_DIR)
print("FULL_PATH:", FULL_PATH)

main_df = pd.read_csv(FULL_PATH)
df = main_df.copy()

print("데이터 크기:", df.shape)
display(df.head())
# Out:
# 호출 폴더
# DATA_DIR: C:\Users\joon5\Documents\github\steam-indie-game-analysis\data\processed
# FULL_PATH: C:\Users\joon5\Documents\github\steam-indie-game-analysis\data\processed\steam_indie_review_histogram_preprocessed_lee_v2.csv
# 데이터 크기: (11782, 16)
#     appid                   name        stratum release_date hist_start_date  \
# 0  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 1  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 2  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 3  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 4  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
#
#   hist_end_date        date  recommendations_up  recommendations_down  \
# 0    2026-04-05  2026-03-07                   0                     0
# 1    2026-04-05  2026-03-08                   0                     0
# 2    2026-04-05  2026-03-09                   0                     0
# 3    2026-04-05  2026-03-10                   0                     0
# 4    2026-04-05  2026-03-11                   0                     0
#
#   data_type review_date  recommendations_total  days_from_release  \
# 0    recent  2026-03-07                      0                556
# 1    recent  2026-03-08                      0                557
# 2    recent  2026-03-09                      0                558
# 3    recent  2026-03-10                      0                559
# 4    recent  2026-03-11                      0                560
#
#    is_before_release_review release_period             histogram_key
# 0                     False      D181_plus  402160_2026-03-07_recent
# 1                     False      D181_plus  402160_2026-03-08_recent
# 2                     False      D181_plus  402160_2026-03-09_recent
# 3                     False      D181_plus  402160_2026-03-10_recent
# 4                     False      D181_plus  402160_2026-03-11_recent

# %% [markdown]
# # 간단 점검

# %%
def check_basic_info(df, df_name, exclude_cols=None):
    """행/열 수, 완전 중복 행, 컬럼별 타입/결측/고유값을 한 번에 확인"""
    print(f"\n{'='*80}")
    print(f"{df_name}의 기본 정보 / 타입 / 결측치 확인")
    print(f"{'='*80}\n")

    # 제외할 컬럼 반영
    df_copied = df.copy()
    if exclude_cols:
        df_copied = df_copied.drop(columns=exclude_cols, errors='ignore')

    # dict, list, set 같은 해시 불가능 값이 들어있는 컬럼은 문자열로 변환
    for col in df_copied.columns:
        try:
            df_copied[col].nunique(dropna=True)
        except TypeError:
            df_copied[col] = df_copied[col].astype(str)

    # 전체 요약
    overview_df = pd.DataFrame({
        '항목': ['행 개수', '열 개수', '중복 행 개수'],
        '값': [df_copied.shape[0], df_copied.shape[1], df_copied.duplicated().sum()]
    })

    summary_df = pd.DataFrame({
        '데이터타입': df_copied.dtypes.astype(str),
        '행 개수': df_copied.count(),
        '행 비율(%)': (df_copied.count() / len(df_copied) * 100).round(2),
        '결측치 개수': df_copied.isnull().sum(),
        '결측치 비율(%)': (df_copied.isnull().sum() / len(df_copied) * 100).round(2),
        '고유값 개수': df_copied.nunique(dropna=True)
    }).sort_values(by=['결측치 개수', '고유값 개수'], ascending=[False, False])

    print("[전체 요약]")
    display(overview_df)

    print("[컬럼별 요약]")
    display(summary_df)

    print("[상위 5행]")
    display(df_copied.head())

# %%
check_basic_info(df, "df_hist")
# Out:
# ================================================================================
# df_hist의 기본 정보 / 타입 / 결측치 확인
# ================================================================================
#
# [전체 요약]
#         항목      값
# 0     행 개수  11782
# 1     열 개수     16
# 2  중복 행 개수      0
# [컬럼별 요약]
#                           데이터타입   행 개수  행 비율(%)  결측치 개수  결측치 비율(%)  고유값 개수
# histogram_key               str  11782    100.0       0        0.0   11782
# days_from_release         int64  11782    100.0       0        0.0    1904
# date                        str  11782    100.0       0        0.0     995
# review_date                 str  11782    100.0       0        0.0     995
# recommendations_total     int64  11782    100.0       0        0.0     334
# recommendations_up        int64  11782    100.0       0        0.0     321
# appid                     int64  11782    100.0       0        0.0     200
# name                        str  11782    100.0       0        0.0     200
# release_date                str  11782    100.0       0        0.0     177
# hist_start_date             str  11782    100.0       0        0.0     177
# hist_end_date               str  11782    100.0       0        0.0     112
# recommendations_down      int64  11782    100.0       0        0.0      87
# stratum                     str  11782    100.0       0        0.0      24
# release_period              str  11782    100.0       0        0.0       6
# data_type                   str  11782    100.0       0        0.0       2
# is_before_release_review   bool  11782    100.0       0        0.0       2
# [상위 5행]
#     appid                   name        stratum release_date hist_start_date  \
# 0  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 1  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 2  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 3  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 4  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
#
#   hist_end_date        date  recommendations_up  recommendations_down  \
# 0    2026-04-05  2026-03-07                   0                     0
# 1    2026-04-05  2026-03-08                   0                     0
# 2    2026-04-05  2026-03-09                   0                     0
# 3    2026-04-05  2026-03-10                   0                     0
# 4    2026-04-05  2026-03-11                   0                     0
#
#   data_type review_date  recommendations_total  days_from_release  \
# 0    recent  2026-03-07                      0                556
# 1    recent  2026-03-08                      0                557
# 2    recent  2026-03-09                      0                558
# 3    recent  2026-03-10                      0                559
# 4    recent  2026-03-11                      0                560
#
#    is_before_release_review release_period             histogram_key
# 0                     False      D181_plus  402160_2026-03-07_recent
# 1                     False      D181_plus  402160_2026-03-08_recent
# 2                     False      D181_plus  402160_2026-03-09_recent
# 3                     False      D181_plus  402160_2026-03-10_recent
# 4                     False      D181_plus  402160_2026-03-11_recent

# %%
def check_steam_info(data, data_name="data"):
    """
    스팀 게임 데이터의 기본 구조를 빠르게 확인하는 함수
    """
    print("=" * 80)
    print(f"{data_name} 기본 정보")
    print("=" * 80)
    print("행/열:", data.shape)
    print("중복 행 수:", data.duplicated().sum())
    print("게임 수:", data["appid"].nunique() if "appid" in data.columns else "appid 없음")

    info = pd.DataFrame({
        "column": data.columns,
        "dtype": data.dtypes.astype(str).values,
        "missing_count": data.isna().sum().values,
        "missing_ratio": (data.isna().mean() * 100).round(2).values,
        "nunique": data.nunique(dropna=False).values
    })
    
    display(info)


check_basic_info(df, "review_histogram")

print("\ndata_type 분포")
display(df["data_type"].value_counts(dropna=False).reset_index())

print("\nrelease_period 분포")
display(df["release_period"].value_counts(dropna=False).reset_index())
# Out:
# ================================================================================
# review_histogram의 기본 정보 / 타입 / 결측치 확인
# ================================================================================
#
# [전체 요약]
#         항목      값
# 0     행 개수  11782
# 1     열 개수     16
# 2  중복 행 개수      0
# [컬럼별 요약]
#                           데이터타입   행 개수  행 비율(%)  결측치 개수  결측치 비율(%)  고유값 개수
# histogram_key               str  11782    100.0       0        0.0   11782
# days_from_release         int64  11782    100.0       0        0.0    1904
# date                        str  11782    100.0       0        0.0     995
# review_date                 str  11782    100.0       0        0.0     995
# recommendations_total     int64  11782    100.0       0        0.0     334
# recommendations_up        int64  11782    100.0       0        0.0     321
# appid                     int64  11782    100.0       0        0.0     200
# name                        str  11782    100.0       0        0.0     200
# release_date                str  11782    100.0       0        0.0     177
# hist_start_date             str  11782    100.0       0        0.0     177
# hist_end_date               str  11782    100.0       0        0.0     112
# recommendations_down      int64  11782    100.0       0        0.0      87
# stratum                     str  11782    100.0       0        0.0      24
# release_period              str  11782    100.0       0        0.0       6
# data_type                   str  11782    100.0       0        0.0       2
# is_before_release_review   bool  11782    100.0       0        0.0       2
# [상위 5행]
#     appid                   name        stratum release_date hist_start_date  \
# 0  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 1  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 2  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 3  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
# 4  402160  Star Command Galaxies  Strategy_high   2024-08-28      2015-09-17
#
#   hist_end_date        date  recommendations_up  recommendations_down  \
# 0    2026-04-05  2026-03-07                   0                     0
# 1    2026-04-05  2026-03-08                   0                     0
# 2    2026-04-05  2026-03-09                   0                     0
# 3    2026-04-05  2026-03-10                   0                     0
# 4    2026-04-05  2026-03-11                   0                     0
#
#   data_type review_date  recommendations_total  days_from_release  \
# 0    recent  2026-03-07                      0                556
# 1    recent  2026-03-08                      0                557
# 2    recent  2026-03-09                      0                558
# 3    recent  2026-03-10                      0                559
# 4    recent  2026-03-11                      0                560
#
#    is_before_release_review release_period             histogram_key
# 0                     False      D181_plus  402160_2026-03-07_recent
# 1                     False      D181_plus  402160_2026-03-08_recent
# 2                     False      D181_plus  402160_2026-03-09_recent
# 3                     False      D181_plus  402160_2026-03-10_recent
# 4                     False      D181_plus  402160_2026-03-11_recent
# data_type 분포
#   data_type  count
# 0    recent   5976
# 1   rollups   5806
# release_period 분포
#    release_period  count
# 0       D181_plus   8737
# 1  before_release    990
# 2         D91_180    875
# 3          D31_90    627
# 4           D8_30    331
# 5            D0_7    222

# %% [markdown]
# # 2. 날짜 컬럼 변환

# %%
date_cols = ["release_date", "hist_start_date", "hist_end_date", "date", "review_date"]

for col in date_cols:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors="coerce")

date_info = pd.DataFrame({
    "column": [col for col in date_cols if col in df.columns],
    "dtype_after": [str(df[col].dtype) for col in date_cols if col in df.columns],
    "missing_count": [df[col].isna().sum() for col in date_cols if col in df.columns]
})

display(date_info)
# Out:
#             column     dtype_after  missing_count
# 0     release_date  datetime64[us]              0
# 1  hist_start_date  datetime64[us]              0
# 2    hist_end_date  datetime64[us]              0
# 3             date  datetime64[us]              0
# 4      review_date  datetime64[us]              0

# %% [markdown]
# # 3. 분석 테이블 생성

# %% [markdown]
# # 3-1. 분석 기준 데이터 선택

# %%
DATA_TYPE_TO_USE = "rollups"

if DATA_TYPE_TO_USE in df["data_type"].unique():
    df_analysis = df[df["data_type"] == DATA_TYPE_TO_USE].copy()
else:
    df_analysis = df.copy()

print("분석 기준 data_type:", DATA_TYPE_TO_USE)
print("분석용 데이터 크기:", df_analysis.shape)
print("분석용 게임 수:", df_analysis["appid"].nunique())

display(
    pd.crosstab(
        df_analysis["release_period"],
        df_analysis["data_type"],
        margins=True
    )
)
# Out:
# 분석 기준 data_type: rollups
# 분석용 데이터 크기: (5806, 16)
# 분석용 게임 수: 200
# data_type       rollups   All
# release_period
# D0_7                192   192
# D181_plus          3015  3015
# D31_90              590   590
# D8_30               284   284
# D91_180             754   754
# before_release      971   971
# All                5806  5806

# %% [markdown]
# # 3-2. 게임 - 출시기간 단위 집계
#
# | 구간 | 의미 |
# |---|---|
# | `before_release` | 출시 전 |
# | `D0_7` | 출시 후 0~7일 |
# | `D8_30` | 출시 후 8~30일 |
# | `D31_90` | 출시 후 31~90일 |
# | `D91_180` | 출시 후 91~180일 |
# | `D181_plus` | 출시 후 181일 이후 |

# %%
period_summary = (
    df_analysis
    .groupby(["appid", "name", "stratum", "release_period"], as_index=False)
    .agg(
        recommendations_up=("recommendations_up", "sum"),
        recommendations_down=("recommendations_down", "sum"),
        recommendations_total=("recommendations_total", "sum")
    )
)

print("게임 - 기간 집계 테이블 크기:", period_summary.shape)
display(period_summary.head())
# Out:
# 게임 - 기간 집계 테이블 크기: (926, 7)
#     appid                   name        stratum  release_period  \
# 0  402160  Star Command Galaxies  Strategy_high            D0_7
# 1  402160  Star Command Galaxies  Strategy_high       D181_plus
# 2  402160  Star Command Galaxies  Strategy_high          D31_90
# 3  402160  Star Command Galaxies  Strategy_high         D91_180
# 4  402160  Star Command Galaxies  Strategy_high  before_release
#
#    recommendations_up  recommendations_down  recommendations_total
# 0                   2                     3                      5
# 1                   9                    20                     29
# 2                   1                     2                      3
# 3                   2                     4                      6
# 4                 150                   190                    340

# %% [markdown]
# ## 3-3. 기간별 리뷰 수를 게임 단위로 펼치기

# %%
period_order = [
    "before_release",
    "D0_7",
    "D8_30",
    "D31_90",
    "D91_180",
    "D181_plus"
]

def make_period_pivot(data, value_col, suffix):
    pivot = (
        data
        .pivot_table(
            index=["appid", "name", "stratum"],
            columns="release_period",
            values=value_col,
            aggfunc="sum",
            fill_value=0
        )
        .reset_index()
    )

    pivot.columns = [
        col if col in ["appid", "name", "stratum"] else f"{col}_{suffix}"
        for col in pivot.columns
    ]

    return pivot

total_pivot = make_period_pivot(period_summary, "recommendations_total", "total")
up_pivot = make_period_pivot(period_summary, "recommendations_up", "up")
down_pivot = make_period_pivot(period_summary, "recommendations_down", "down")

game_summary = (
    total_pivot
    .merge(up_pivot, on=["appid", "name", "stratum"], how="left")
    .merge(down_pivot, on=["appid", "name", "stratum"], how="left")
)

# 누락된 기간 컬럼은 0으로 생성
for period in period_order:
    for suffix in ["total", "up", "down"]:
        col = f"{period}_{suffix}"
        if col not in game_summary.columns:
            game_summary[col] = 0

print("게임 단위 요약 데이터 크기:", game_summary.shape)
display(game_summary.head())
# Out:
# 게임 단위 요약 데이터 크기: (200, 21)
#     appid                                name         stratum  D0_7_total  \
# 0  402160               Star Command Galaxies   Strategy_high           5
# 1  437440                       Lord of Rigel    Strategy_mid          12
# 2  444690                             TRAPPED   Strategy_high           0
# 3  571740                            Golf It!     Sports_high           0
# 4  597920  Survivalizm - The Animal Simulator  Simulation_mid           0
#
#    D181_plus_total  D31_90_total  D8_30_total  D91_180_total  \
# 0               29             3            0              6
# 1               22             4            0              7
# 2                2             0            2              6
# 3             3931          2256          206            523
# 4                0             0            3              1
#
#    before_release_total  D0_7_up  D181_plus_up  D31_90_up  D8_30_up  \
# 0                   340        2             9          1         0
# 1                    53       10            14          4         0
# 2                   259        0             1          0         1
# 3                 18854        0          3497       2201       186
# 4                    75        0             0          0         3
#
#    D91_180_up  before_release_up  D0_7_down  D181_plus_down  D31_90_down  \
# 0           2                150          3              20            2
# 1           5                 34          2               8            0
# 2           3                120          0               1            0
# 3         455              16877          0             434           55
# 4           0                 29          0               0            0
#
#    D8_30_down  D91_180_down  before_release_down
# 0           0             4                  190
# 1           0             2                   19
# 2           1             3                  139
# 3          20            68                 1977
# 4           0             1                   46

# %% [markdown]
# ## 3-4. 분석용 핵심 지표 생성
#
# | 지표 | 의미 |
# |---|---|
# | `early_reviews_d0_30` | 출시 후 30일 리뷰 수 |
# | `early_positive_ratio_d0_30` | 출시 후 30일 단순 긍정률 |
# | `early_wilson_d0_30` | 리뷰 수를 보정한 초기 긍정 품질 지표 |
# | `later_reviews_d31_180` | 출시 후 31~180일 리뷰 수 |
# | `retention_d31_180_vs_d0_30` | 초기 대비 이후 리뷰 유지율 |

# %%
def safe_ratio(numerator, denominator):
    """
    0으로 나누는 문제를 피하기 위한 비율 계산 함수
    denominator가 0이면 NaN을 반환한다.
    """
    return np.where(denominator > 0, numerator / denominator, np.nan)


def wilson_lower_bound(pos, total, z=1.96):
    """
    Wilson Score Lower Bound 계산 함수

    리뷰 수가 적은 게임의 긍정률 과대평가를 줄이기 위해 사용한다.
    """
    pos = np.asarray(pos)
    total = np.asarray(total)

    result = np.full_like(total, np.nan, dtype=float)
    mask = total > 0

    p = pos[mask] / total[mask]
    n = total[mask]

    denominator = 1 + z**2 / n
    center = p + z**2 / (2 * n)
    margin = z * np.sqrt((p * (1 - p) + z**2 / (4 * n)) / n)

    result[mask] = (center - margin) / denominator

    return result

# %% [markdown]
# ## 3-4-1. 리뷰 규모 지표

# %%
game_summary["before_release_reviews"] = game_summary["before_release_total"]

game_summary["early_reviews_d0_7"] = game_summary["D0_7_total"]
game_summary["early_reviews_d8_30"] = game_summary["D8_30_total"]

game_summary["early_reviews_d0_30"] = (
    game_summary["D0_7_total"] +
    game_summary["D8_30_total"]
)

game_summary["mid_reviews_d31_90"] = game_summary["D31_90_total"]
game_summary["long_reviews_d91_180"] = game_summary["D91_180_total"]
game_summary["long_reviews_d181_plus"] = game_summary["D181_plus_total"]

game_summary["later_reviews_d31_180"] = (
    game_summary["D31_90_total"] +
    game_summary["D91_180_total"]
)

game_summary["post_release_reviews_total"] = (
    game_summary["D0_7_total"] +
    game_summary["D8_30_total"] +
    game_summary["D31_90_total"] +
    game_summary["D91_180_total"] +
    game_summary["D181_plus_total"]
)

# %% [markdown]
# ## 3-4-2. 긍정률 지표

# %%
game_summary["early_positive_ratio_d0_30"] = safe_ratio(
    game_summary["D0_7_up"] + game_summary["D8_30_up"],
    game_summary["early_reviews_d0_30"]
)

game_summary["mid_positive_ratio_d31_90"] = safe_ratio(
    game_summary["D31_90_up"],
    game_summary["D31_90_total"]
)

game_summary["long_positive_ratio_d91_180"] = safe_ratio(
    game_summary["D91_180_up"],
    game_summary["D91_180_total"]
)

game_summary["post_release_positive_ratio"] = safe_ratio(
    game_summary["D0_7_up"] +
    game_summary["D8_30_up"] +
    game_summary["D31_90_up"] +
    game_summary["D91_180_up"] +
    game_summary["D181_plus_up"],
    game_summary["post_release_reviews_total"]
)

# %% [markdown]
# ## 3-4-3. Wilson score 지표

# %%
game_summary["early_wilson_d0_30"] = wilson_lower_bound(
    game_summary["D0_7_up"] + game_summary["D8_30_up"],
    game_summary["early_reviews_d0_30"]
)

game_summary["post_release_wilson"] = wilson_lower_bound(
    game_summary["D0_7_up"] +
    game_summary["D8_30_up"] +
    game_summary["D31_90_up"] +
    game_summary["D91_180_up"] +
    game_summary["D181_plus_up"],
    game_summary["post_release_reviews_total"]
)

# %% [markdown]
# ## 3-4-4. 유지율 지표

# %%
game_summary["retention_d31_90_vs_d0_30"] = safe_ratio(
    game_summary["mid_reviews_d31_90"],
    game_summary["early_reviews_d0_30"]
)

game_summary["retention_d31_180_vs_d0_30"] = safe_ratio(
    game_summary["later_reviews_d31_180"],
    game_summary["early_reviews_d0_30"]
)

game_summary["retention_d181_plus_vs_d0_30"] = safe_ratio(
    game_summary["long_reviews_d181_plus"],
    game_summary["early_reviews_d0_30"]
)

# %% [markdown]
# ## 3-4-5. stratum 분리

# %%
game_summary["genre_group"] = game_summary["stratum"].str.rsplit("_", n=1).str[0]
game_summary["review_tier"] = game_summary["stratum"].str.rsplit("_", n=1).str[1]

# %% [markdown]
# ## 3-5. 최종 분석용 테이블 정리

# %%
analysis_cols = [
    "appid",
    "name",
    "stratum",
    "genre_group",
    "review_tier",

    "before_release_reviews",
    "early_reviews_d0_7",
    "early_reviews_d8_30",
    "early_reviews_d0_30",
    "mid_reviews_d31_90",
    "long_reviews_d91_180",
    "long_reviews_d181_plus",
    "later_reviews_d31_180",
    "post_release_reviews_total",

    "early_positive_ratio_d0_30",
    "early_wilson_d0_30",
    "mid_positive_ratio_d31_90",
    "long_positive_ratio_d91_180",
    "post_release_positive_ratio",
    "post_release_wilson",

    "retention_d31_90_vs_d0_30",
    "retention_d31_180_vs_d0_30",
    "retention_d181_plus_vs_d0_30",
]

final_reaction_df = game_summary[analysis_cols].copy()

print("최종 분석 테이블 크기:", final_reaction_df.shape)
display(final_reaction_df.head())
# Out:
# 최종 분석 테이블 크기: (200, 23)
#     appid                                name         stratum genre_group  \
# 0  402160               Star Command Galaxies   Strategy_high    Strategy
# 1  437440                       Lord of Rigel    Strategy_mid    Strategy
# 2  444690                             TRAPPED   Strategy_high    Strategy
# 3  571740                            Golf It!     Sports_high      Sports
# 4  597920  Survivalizm - The Animal Simulator  Simulation_mid  Simulation
#
#   review_tier  before_release_reviews  early_reviews_d0_7  \
# 0        high                     340                   5
# 1         mid                      53                  12
# 2        high                     259                   0
# 3        high                   18854                   0
# 4         mid                      75                   0
#
#    early_reviews_d8_30  early_reviews_d0_30  mid_reviews_d31_90  \
# 0                    0                    5                   3
# 1                    0                   12                   4
# 2                    2                    2                   0
# 3                  206                  206                2256
# 4                    3                    3                   0
#
#    long_reviews_d91_180  long_reviews_d181_plus  later_reviews_d31_180  \
# 0                     6                      29                      9
# 1                     7                      22                     11
# 2                     6                       2                      6
# 3                   523                    3931                   2779
# 4                     1                       0                      1
#
#    post_release_reviews_total  early_positive_ratio_d0_30  early_wilson_d0_30  \
# 0                          43                    0.400000            0.117618
# 1                          45                    0.833333            0.551964
# 2                          10                    0.500000            0.094529
# 3                        6916                    0.902913            0.854803
# 4                           4                    1.000000            0.438494
#
#    mid_positive_ratio_d31_90  long_positive_ratio_d91_180  \
# 0                   0.333333                     0.333333
# 1                   1.000000                     0.714286
# 2                        NaN                     0.500000
# 3                   0.975621                     0.869981
# 4                        NaN                     0.000000
#
#    post_release_positive_ratio  post_release_wilson  \
# 0                     0.325581             0.204931
# 1                     0.733333             0.589609
# 2                     0.500000             0.236590
# 3                     0.916570             0.909819
# 4                     0.750000             0.300636
#
#    retention_d31_90_vs_d0_30  retention_d31_180_vs_d0_30  \
# 0                   0.600000                    1.800000
# 1                   0.333333                    0.916667
# 2                   0.000000                    3.000000
# 3                  10.951456                   13.490291
# 4                   0.000000                    0.333333
#
#    retention_d181_plus_vs_d0_30
# 0                      5.800000
# 1                      1.833333
# 2                      1.000000
# 3                     19.082524
# 4                      0.000000

# %% [markdown]
# # 4. 분석 시작 1: 초기 반응 규모 분석

# %% [markdown]
# ## 무엇을 보는가?
# 초기 반응 규모는 **출시 후 30일 동안 리뷰가 얼마나 쌓였는가**로 본다. (임의 설정)
# - `early_reviews_d0_30`
# - `early_reviews_d0_7`
# - `early_reviews_d8_30`

# %%
scale_summary = final_reaction_df[
    [
        "early_reviews_d0_7",
        "early_reviews_d8_30",
        "early_reviews_d0_30",
        "post_release_reviews_total"
    ]
].describe().T

display(scale_summary)

print("초기 리뷰 수 상위 20개 게임")
top_early_games = (
    final_reaction_df
    .sort_values("early_reviews_d0_30", ascending=False)
    .head(20)
)

display(
    top_early_games[
        [
            "appid",
            "name",
            "stratum",
            "early_reviews_d0_7",
            "early_reviews_d8_30",
            "early_reviews_d0_30",
            "post_release_reviews_total",
            "early_positive_ratio_d0_30"
        ]
    ]
)
# Out:
#                             count      mean          std  min    25%   50%  \
# early_reviews_d0_7          200.0   300.725  2768.913182  0.0   0.00   5.0
# early_reviews_d8_30         200.0   179.275  1354.200426  0.0   0.00   3.0
# early_reviews_d0_30         200.0   480.000  3960.554603  0.0   4.00  11.0
# post_release_reviews_total  200.0  1146.295  7938.518105  0.0  13.75  41.5
#
#                               75%      max
# early_reviews_d0_7           23.0  38068.0
# early_reviews_d8_30          15.5  13566.0
# early_reviews_d0_30          50.0  51634.0
# post_release_reviews_total  195.5  93444.0
# 초기 리뷰 수 상위 20개 게임
#        appid                                        name         stratum  \
# 29   1671210                                   DELTARUNE        RPG_high
# 179  3146520                                  WEBFISHING     Casual_high
# 187  3244220                A Game About Digging A Hole™  Adventure_high
# 53   1996010                                Crow Country     Action_high
# 183  3205080               Bad Parenting 1: Mr. Red Face  Adventure_high
# 125  2585830                       Promise Mascot Agency        RPG_high
# 124  2581050                   KAMITSUBAKI CITY ENSEMBLE     Sports_high
# 5     695330              SEASON: A letter to the future     Casual_high
# 41   1811990                                   Wildfrost   Strategy_high
# 153  2820820                 Jotunnslayer: Hordes of Hel        RPG_high
# 185  3215170  NEEDY STREAMER OVERLOAD: Typing of The Net     Action_high
# 139  2703850         Rooftops & Alleys: The Parkour Game     Sports_high
# 126  2600600                     Internet Cafe Evolution   Strategy_high
# 34   1709880                                 Loco Motive  Adventure_high
# 94   2390230                            The Chef's Shift   Strategy_high
# 27   1640630                                 Heading Out     Racing_high
# 31   1671720                           Athenian Rhapsody         RPG_mid
# 3     571740                                    Golf It!     Sports_high
# 130  2629330                             MEMOLOGY: GOYDA     Sports_high
# 37   1747760                  Momodora: Moonlit Farewell     Action_high
#
#      early_reviews_d0_7  early_reviews_d8_30  early_reviews_d0_30  \
# 29                38068                13566                51634
# 179                6531                13271                19802
# 187                6865                 3091                 9956
# 53                 1555                  616                 2171
# 183                 564                  544                 1108
# 125                 705                  277                  982
# 124                 740                   87                  827
# 5                   568                  115                  683
# 41                    0                  678                  678
# 153                 318                  294                  612
# 185                 428                   43                  471
# 139                 158                  283                  441
# 126                 271                  133                  404
# 34                  270                  113                  383
# 94                  243                   67                  310
# 27                  240                   37                  277
# 31                  199                   39                  238
# 3                     0                  206                  206
# 130                 116                   62                  178
# 37                    0                  174                  174
#
#      post_release_reviews_total  early_positive_ratio_d0_30
# 29                        93444                    0.985126
# 179                       59785                    0.978184
# 187                       18363                    0.902772
# 53                         6932                    0.986642
# 183                        3094                    0.967509
# 125                        2379                    0.981670
# 124                        1403                    0.646917
# 5                          1802                    0.935578
# 41                         4259                    0.805310
# 153                        2249                    0.795752
# 185                         785                    0.726115
# 139                        1241                    0.882086
# 126                         623                    0.742574
# 34                         1071                    0.947781
# 94                         1534                    0.964516
# 27                          632                    0.783394
# 31                          337                    0.920168
# 3                          6916                    0.902913
# 130                        1908                    0.842697
# 37                         1675                    0.908046

# %% [markdown]
# ## 초기 리뷰 수 분포 시각화

# %%
# 원본 분포
plt.figure(figsize=(10, 5))
sns.histplot(
    data=final_reaction_df,
    x="early_reviews_d0_30",
    bins=30
)
plt.title("출시 후 30일 초기 리뷰 수 분포")
plt.xlabel("D0~30 리뷰 수")
plt.ylabel("게임 수")
plt.show()

# 로그 변환 분포
plt.figure(figsize=(10, 5))
sns.histplot(
    x=np.log1p(final_reaction_df["early_reviews_d0_30"]),
    bins=30
)
plt.title("출시 후 30일 초기 리뷰 수 분포 - log1p")
plt.xlabel("log1p(D0~30 리뷰 수)")
plt.ylabel("게임 수")
plt.show()

# %% [markdown]
# - 초기 리뷰 수가 높으면 출시 직후 관심을 많이 받은 게임으로 볼 수 있다.
# - 다만 리뷰 수 분포가 치우쳐 있으면 평균보다 **중앙값, 분위수, 로그 변환 그래프**를 같이 봐야 한다.
# - 이 단계는 "초기 반응 규모"를 보는 것으로, "좋은 반응인지"는 다음 품질 분석에서 따로 확인한다.

# %% [markdown]
# ## 추가 그래프: 초기 리뷰 수 상위 게임

# %%
# 추가 그래프 1: D0~30 초기 리뷰 수 상위 20개 게임
top_early_plot = top_early_games.sort_values("early_reviews_d0_30", ascending=True)

plt.figure(figsize=(10, 8))
sns.barplot(
    data=top_early_plot,
    x="early_reviews_d0_30",
    y="name"
)
plt.title("D0~30 초기 리뷰 수 상위 20개 게임")
plt.xlabel("D0~30 리뷰 수")
plt.ylabel("게임명")
plt.show()

# %% [markdown]
# # 5. 분석 시작 2: 초기 반응 품질 분석

# %% [markdown]
# ## 무엇을 보는가
#
# 초기 반응 품질은 단순 긍정률만 보면 위험하다.\
# 리뷰 수가 1~2개인 게임은 긍정률이 쉽게 100%가 될 수 있기 때문이다.
#
# 때문에 두 지표를 함께 확인한다.
#
# - `early_positive_ratio_d0_30` :출시 후 30일 단순 긍정률
# - `early_wilson_d0_30` :리뷰 수를 고려한 보정 긍정률

# %%
quality_summary = final_reaction_df[
    [
        "early_positive_ratio_d0_30",
        "early_wilson_d0_30",
        "post_release_positive_ratio",
        "post_release_wilson"
    ]
].describe().T

display(quality_summary)

print("초기 리뷰 수 10개 이상 기준 Wilson 상위 20개 게임")
top_quality_games = (
    final_reaction_df[final_reaction_df["early_reviews_d0_30"] >= 10]
    .sort_values("early_wilson_d0_30", ascending=False)
    .head(20)
)

display(
    top_quality_games[
        [
            "appid",
            "name",
            "stratum",
            "early_reviews_d0_30",
            "early_positive_ratio_d0_30",
            "early_wilson_d0_30",
            "post_release_reviews_total",
            "post_release_wilson"
        ]
    ]
)
# Out:
#                              count      mean       std  min       25%  \
# early_positive_ratio_d0_30   185.0  0.847878  0.193300  0.0  0.775510
# early_wilson_d0_30           185.0  0.588386  0.236899  0.0  0.438494
# post_release_positive_ratio  198.0  0.808627  0.170960  0.0  0.728147
# post_release_wilson          198.0  0.654494  0.204848  0.0  0.551964
#
#                                   50%       75%       max
# early_positive_ratio_d0_30   0.913043  1.000000  1.000000
# early_wilson_d0_30           0.622635  0.766300  0.984045
# post_release_positive_ratio  0.855655  0.923537  1.000000
# post_release_wilson          0.675584  0.809898  0.981248
# 초기 리뷰 수 10개 이상 기준 Wilson 상위 20개 게임
#        appid                                          name         stratum  \
# 29   1671210                                     DELTARUNE        RPG_high
# 53   1996010                                  Crow Country     Action_high
# 179  3146520                                    WEBFISHING     Casual_high
# 125  2585830                         Promise Mascot Agency        RPG_high
# 183  3205080                 Bad Parenting 1: Mr. Red Face  Adventure_high
# 182  3198680                                       Puttler      Sports_mid
# 94   2390230                              The Chef's Shift   Strategy_high
# 140  2707110                        Birds Organized Neatly      Casual_mid
# 180  3155430                           FIND ALL 5: Vikings      Casual_mid
# 95   2393770  Bang Average Football – Play, Manage, Create      Sports_mid
# 34   1709880                                   Loco Motive  Adventure_high
# 5     695330                SEASON: A letter to the future     Casual_high
# 187  3244220                  A Game About Digging A Hole™  Adventure_high
# 51   1921470                                       TAGLINE      Racing_mid
# 31   1671720                             Athenian Rhapsody         RPG_mid
# 174  3081830                            FLARE NUINUI QUEST      Action_mid
# 175  3089700                                  Whiskey-Four         RPG_mid
# 103  2453400                        Ru Lin Wai Shi Fan Jin         RPG_mid
# 102  2444290                                   Hyper Space    Strategy_mid
# 109  2485750                 Midnight Scenes: A Safe Place   Adventure_mid
#
#      early_reviews_d0_30  early_positive_ratio_d0_30  early_wilson_d0_30  \
# 29                 51634                    0.985126            0.984045
# 53                  2171                    0.986642            0.980882
# 179                19802                    0.978184            0.976055
# 125                  982                    0.981670            0.971212
# 183                 1108                    0.967509            0.955347
# 182                  148                    0.986486            0.952070
# 94                   310                    0.964516            0.937587
# 140                   80                    0.987500            0.932536
# 180                  121                    0.975207            0.929634
# 95                    50                    1.000000            0.928650
# 34                   383                    0.947781            0.920723
# 5                    683                    0.935578            0.914621
# 187                 9956                    0.902772            0.896796
# 51                    29                    1.000000            0.883026
# 31                   238                    0.920168            0.878688
# 174                  119                    0.932773            0.872934
# 175                   65                    0.953846            0.872859
# 103                   53                    0.962264            0.872455
# 102                   26                    1.000000            0.871267
# 109                   39                    0.974359            0.868187
#
#      post_release_reviews_total  post_release_wilson
# 29                        93444             0.981248
# 53                         6932             0.975905
# 179                       59785             0.974020
# 125                        2379             0.956494
# 183                        3094             0.885685
# 182                         234             0.917798
# 94                         1534             0.967682
# 140                         298             0.939340
# 180                         345             0.915592
# 95                          348             0.933613
# 34                         1071             0.911056
# 5                          1802             0.914384
# 187                       18363             0.888493
# 51                           54             0.824456
# 31                          337             0.882538
# 174                         244             0.886415
# 175                         102             0.877563
# 103                          96             0.870289
# 102                          35             0.901096
# 109                         175             0.898020

# %% [markdown]
# ## 초기 규모와 품질의 관계
#
# 초기 리뷰 수가 많다고 반드시 품질이 좋은 것은 아니기 때문에
# 아래 그래프는 **초기 반응 규모**와 **Wilson 기준 품질**을 함께 본다.

# %%
plot_df = final_reaction_df.copy()
plot_df["log_early_reviews"] = np.log1p(plot_df["early_reviews_d0_30"])

plt.figure(figsize=(9, 6))
sns.scatterplot(
    data=plot_df,
    x="log_early_reviews",
    y="early_wilson_d0_30",
    hue="review_tier",
    alpha=0.8
)
plt.title("초기 리뷰 수 규모와 Wilson 품질 지표의 관계")
plt.xlabel("log1p(D0~30 리뷰 수)")
plt.ylabel("초기 Wilson score")
plt.legend(title="review_tier", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %% [markdown]
# ### 해석
#
# - 오른쪽 위: 초기 반응도 크고 품질도 좋은 게임
# - 오른쪽 아래: 초기 관심은 받았지만 품질 위험이 있는 게임
# - 왼쪽 위: 노출은 작지만 반응 품질이 좋은 게임
# - 왼쪽 아래: 초기 반응 규모와 품질이 모두 약한 게임

# %% [markdown]
# ## 추가 그래프: Wilson score 상위 게임
#
# 보고서에서 초기 반응 품질이 높은 게임을 설명할 때 사용할 수 있는 막대그래프입니다.
# 기존 `top_quality_games` 테이블을 그대로 활용합니다.

# %%
# 추가 그래프 2: 초기 Wilson score 상위 20개 게임
top_quality_plot = top_quality_games.sort_values("early_wilson_d0_30", ascending=True)

plt.figure(figsize=(10, 8))
sns.barplot(
    data=top_quality_plot,
    x="early_wilson_d0_30",
    y="name"
)
plt.title("초기 Wilson score 상위 20개 게임")
plt.xlabel("D0~30 Wilson score")
plt.ylabel("게임명")
plt.xlim(0, 1)
plt.show()

# %% [markdown]
# # 6. 분석 시작 3: 초기 이후 반응 유지력 분석
# 초기 반응이 좋은 게임이 이후에도 계속 반응을 유지하는지 확인한다.
#
# 사용 지표
# - later_reviews_d31_180 : 출시 후 31~180일 리뷰 수
# - retention_d31_180_vs_d0_30 : 초기 30일 대비 31~180일 리뷰 유지율

# %%
retention_summary = final_reaction_df[
    [
        "early_reviews_d0_30",
        "later_reviews_d31_180",
        "retention_d31_90_vs_d0_30",
        "retention_d31_180_vs_d0_30",
        "retention_d181_plus_vs_d0_30"
    ]
].describe().T

display(retention_summary)

print("D31~180 유지율 상위 20개 게임")
top_retention_games = (
    final_reaction_df
    .dropna(subset=["retention_d31_180_vs_d0_30"])
    .sort_values("retention_d31_180_vs_d0_30", ascending=False)
    .head(20)
)

display(
    top_retention_games[
        [
            "appid",
            "name",
            "stratum",
            "early_reviews_d0_30",
            "later_reviews_d31_180",
            "retention_d31_180_vs_d0_30",
            "early_wilson_d0_30"
        ]
    ]
)
# Out:
#                               count        mean          std  min       25%  \
# early_reviews_d0_30           200.0  480.000000  3960.554603  0.0  4.000000
# later_reviews_d31_180         200.0  432.815000  3265.619485  0.0  3.000000
# retention_d31_90_vs_d0_30     185.0    0.777824     1.252644  0.0  0.105263
# retention_d31_180_vs_d0_30    185.0    1.630053     2.979500  0.0  0.264706
# retention_d181_plus_vs_d0_30  185.0    2.867787     7.168117  0.0  0.308725
#
#                                     50%        75%           max
# early_reviews_d0_30           11.000000  50.000000  51634.000000
# later_reviews_d31_180         11.000000  44.750000  33823.000000
# retention_d31_90_vs_d0_30      0.380000   1.000000     10.951456
# retention_d31_180_vs_d0_30     0.700000   2.000000     24.000000
# retention_d181_plus_vs_d0_30   0.833333   3.055556     83.500000
# D31~180 유지율 상위 20개 게임
#        appid                           name          stratum  \
# 38   1771180                   No Fair Play      Sports_high
# 117  2538390                  Angry Penguin       Action_mid
# 3     571740                       Golf It!      Sports_high
# 24   1562260   Camping Simulator: The Squad  Simulation_high
# 70   2217580                   New Star™ GP      Racing_high
# 61   2141770                           URBO      Casual_high
# 78   2276960             a land Goo's crazy          RPG_low
# 118  2539070  I commissioned some bunnies 2       Casual_low
# 63   2153020         Pilfer: Story of Light       Action_mid
# 66   2187230                         ALTF42      Racing_high
# 52   1945230               Diablo The Abyss     Strategy_mid
# 60   2128690              Super Block Crush       Sports_low
# 11   1147940                       3dSen PC      Racing_high
# 88   2340290                 Dungeon Knight       Action_low
# 57   2086850             Guardians of Holme     Strategy_mid
# 132  2641350      YoloX - Crosshair Overlay       Action_mid
# 161  2907190                     April 24th  Simulation_high
# 80   2294910    Fish Simulator: Agonik Lake   Simulation_mid
# 33   1703020                    SpaceKraft!   Simulation_mid
# 83   2320040      Skies above the Great War     Strategy_mid
#
#      early_reviews_d0_30  later_reviews_d31_180  retention_d31_180_vs_d0_30  \
# 38                     4                     96                   24.000000
# 117                    8                    186                   23.250000
# 3                    206                   2779                   13.490291
# 24                    11                    127                   11.545455
# 70                    28                    321                   11.464286
# 61                    27                    165                    6.111111
# 78                     1                      6                    6.000000
# 118                    1                      6                    6.000000
# 63                     2                      9                    4.500000
# 66                     5                     22                    4.400000
# 52                     9                     37                    4.111111
# 60                     1                      4                    4.000000
# 11                    14                     56                    4.000000
# 88                     1                      4                    4.000000
# 57                     7                     27                    3.857143
# 132                    3                     11                    3.666667
# 161                   75                    273                    3.640000
# 80                     5                     18                    3.600000
# 33                     4                     13                    3.250000
# 83                    12                     39                    3.250000
#
#      early_wilson_d0_30
# 38             0.300636
# 117            0.529105
# 3              0.854803
# 24             0.212710
# 70             0.822874
# 61             0.766300
# 78             0.206543
# 118            0.206543
# 63             0.342372
# 66             0.230720
# 52             0.700847
# 60             0.206543
# 11             0.524103
# 88             0.206543
# 57             0.486865
# 132            0.061490
# 161            0.803384
# 80             0.565509
# 33             0.510100
# 83             0.551964

# %% [markdown]
# ## 추가 그래프: D31~180 유지율 상위 게임

# %%
# 추가 그래프 3: D31~180 유지율 상위 20개 게임
top_retention_plot = top_retention_games.sort_values("retention_d31_180_vs_d0_30", ascending=True)

plt.figure(figsize=(10, 8))
sns.barplot(
    data=top_retention_plot,
    x="retention_d31_180_vs_d0_30",
    y="name"
)
plt.title("D31~180 유지율 상위 20개 게임")
plt.xlabel("D31~180 리뷰 수 / D0~30 리뷰 수")
plt.ylabel("게임명")
plt.show()

# %% [markdown]
# ## 초기 리뷰 수와 이후 리뷰 수의 관계
# 초기 리뷰 수와 이후 리뷰 수가 함께 커지는지 확인한다.\
# 분포가 심하게 치우쳐 있으므로 `log1p` 변환 후 산점도로 확인

# %%
temp_corr = final_reaction_df[
    ["early_reviews_d0_30", "later_reviews_d31_180"]
].dropna()

rho, p_value = spearmanr(
    temp_corr["early_reviews_d0_30"],
    temp_corr["later_reviews_d31_180"]
)

print("Spearman 상관분석")
print("대상: early_reviews_d0_30 vs later_reviews_d31_180")
print("spearman rho:", round(rho, 4))
print("p-value:", p_value)
print("n:", len(temp_corr))

plt.figure(figsize=(9, 6))
sns.scatterplot(
    data=final_reaction_df,
    x=np.log1p(final_reaction_df["early_reviews_d0_30"]),
    y=np.log1p(final_reaction_df["later_reviews_d31_180"]),
    hue="review_tier",
    alpha=0.8
)
plt.title("초기 리뷰 수와 이후 리뷰 수 관계")
plt.xlabel("log1p(D0~30 리뷰 수)")
plt.ylabel("log1p(D31~180 리뷰 수)")
plt.legend(title="review_tier", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()
# Out:
# Spearman 상관분석
# 대상: early_reviews_d0_30 vs later_reviews_d31_180
# spearman rho: 0.7127
# p-value: 2.553705275291973e-32
# n: 200

# %% [markdown]
# ## 해석
# - 상관이 높으면 초기 반응 규모가 이후 리뷰 유입과도 이어질 가능성이 있다.
# - 상관이 낮으면 초기 반응과 장기 반응은 별개로 봐야 한다.
# - 초기 리뷰 수가 적지만 이후 리뷰 수가 큰 게임은 **느린 입소문형 후보**로 볼 수 있다.

# %% [markdown]
# # 7. 분석 시작 4: 반응 유형화

# %% [markdown]
# ## 무엇을 하는가
#
# 앞에서 만든 세 가지 축을 기준으로 게임을 유형화
# | 축 | 지표 |
# |---|---|
# | 규모 | `early_reviews_d0_30` |
# | 품질 | `early_wilson_d0_30` |
# | 유지력 | `retention_d31_180_vs_d0_30` |
#
#
# 분위수 기준으로 **낮음 / 보통 / 높음**을 나눈 뒤, 이를 조합해 반응 유형을 만든다.

# %%
valid_early = final_reaction_df[final_reaction_df["early_reviews_d0_30"] > 0].copy()

early_review_q33 = valid_early["early_reviews_d0_30"].quantile(0.33)
early_review_q66 = valid_early["early_reviews_d0_30"].quantile(0.66)

wilson_q33 = valid_early["early_wilson_d0_30"].quantile(0.33)
wilson_q66 = valid_early["early_wilson_d0_30"].quantile(0.66)

retention_q33 = valid_early["retention_d31_180_vs_d0_30"].quantile(0.33)
retention_q66 = valid_early["retention_d31_180_vs_d0_30"].quantile(0.66)

criteria_table = pd.DataFrame({
    "axis": ["초기 규모", "초기 규모", "초기 품질", "초기 품질", "유지력", "유지력"],
    "criteria": ["33% 분위수", "66% 분위수", "33% 분위수", "66% 분위수", "33% 분위수", "66% 분위수"],
    "value": [
        early_review_q33,
        early_review_q66,
        wilson_q33,
        wilson_q66,
        retention_q33,
        retention_q66
    ]
})

display(criteria_table)


def classify_scale(x):
    if pd.isna(x) or x == 0:
        return "반응 없음"
    elif x <= early_review_q33:
        return "낮음"
    elif x <= early_review_q66:
        return "보통"
    else:
        return "높음"


def classify_quality(x):
    if pd.isna(x):
        return "판단 불가"
    elif x <= wilson_q33:
        return "낮음"
    elif x <= wilson_q66:
        return "보통"
    else:
        return "높음"


def classify_retention(x):
    if pd.isna(x):
        return "판단 불가"
    elif x <= retention_q33:
        return "낮음"
    elif x <= retention_q66:
        return "보통"
    else:
        return "높음"


final_reaction_df["early_scale"] = final_reaction_df["early_reviews_d0_30"].apply(classify_scale)
final_reaction_df["early_quality"] = final_reaction_df["early_wilson_d0_30"].apply(classify_quality)
final_reaction_df["reaction_retention"] = final_reaction_df["retention_d31_180_vs_d0_30"].apply(classify_retention)
# Out:
#     axis criteria      value
# 0  초기 규모  33% 분위수   8.000000
# 1  초기 규모  66% 분위수  28.440000
# 2  초기 품질  33% 분위수   0.510100
# 3  초기 품질  66% 분위수   0.727207
# 4    유지력  33% 분위수   0.360927
# 5    유지력  66% 분위수   1.414738

# %% [markdown]
# ## 반응 유형 생성
#
# 유형은 아래의 의미로 해석한다.
#
# | 유형 | 의미 |
# |---|---|
# | 초기 흥행형 | 초기 리뷰 수와 품질이 모두 좋고, 이후 유지도 나쁘지 않음 |
# | 화제성 불안형 | 초기 리뷰 수는 많지만 품질이 낮음 |
# | 초기 관심 후 둔화형 | 초기 리뷰 수는 많지만 이후 유지력이 낮음 |
# | 느린 입소문형 | 초기 규모는 작거나 보통이지만 이후 유지력이 높음 |
# | 저노출 가능형 | 초기 규모는 작지만 품질은 높음 |
# | 품질 위험형 | 품질 지표가 낮음 |
# | 일반형 | 위 조건에 명확히 들어가지 않는 게임 |

# %%
def classify_reaction_type(row):
    scale = row["early_scale"]
    quality = row["early_quality"]
    retention = row["reaction_retention"]

    if scale == "반응 없음":
        return "초기 반응 없음"

    if scale == "높음" and quality == "높음" and retention in ["보통", "높음"]:
        return "초기 흥행형"

    if scale == "높음" and quality == "낮음":
        return "화제성 불안형"

    if scale == "높음" and retention == "낮음":
        return "초기 관심 후 둔화형"

    if scale in ["낮음", "보통"] and retention == "높음":
        return "느린 입소문형"

    if scale == "낮음" and quality == "높음":
        return "저노출 가능형"

    if quality == "낮음":
        return "품질 위험형"

    return "일반형"


final_reaction_df["reaction_type"] = final_reaction_df.apply(classify_reaction_type, axis=1)

reaction_type_count = (
    final_reaction_df["reaction_type"]
    .value_counts()
    .reset_index()
)

display(reaction_type_count)
# Out:
#   reaction_type  count
# 0           일반형     52
# 1       느린 입소문형     50
# 2        초기 흥행형     32
# 3        품질 위험형     31
# 4   초기 관심 후 둔화형     15
# 5      초기 반응 없음     15
# 6       화제성 불안형      5

# %% [markdown]
# ## 요약 그래프

# %%
type_summary = (
    final_reaction_df
    .groupby("reaction_type")
    .agg(
        game_count=("appid", "count"),
        early_reviews_median=("early_reviews_d0_30", "median"),
        early_reviews_mean=("early_reviews_d0_30", "mean"),
        early_wilson_median=("early_wilson_d0_30", "median"),
        retention_median=("retention_d31_180_vs_d0_30", "median"),
        later_reviews_median=("later_reviews_d31_180", "median"),
        post_reviews_median=("post_release_reviews_total", "median")
    )
    .reset_index()
    .sort_values("game_count", ascending=False)
)

display(type_summary)

plt.figure(figsize=(10, 5))
order = final_reaction_df["reaction_type"].value_counts().index

sns.countplot(
    data=final_reaction_df,
    y="reaction_type",
    order=order
)
plt.title("반응 유형 분포")
plt.xlabel("게임 수")
plt.ylabel("반응 유형")
plt.show()
# Out:
#   reaction_type  game_count  early_reviews_median  early_reviews_mean  \
# 1           일반형          52                  15.0           30.480769
# 0       느린 입소문형          50                   5.5            8.480000
# 4        초기 흥행형          32                 133.0         2819.937500
# 5        품질 위험형          31                   4.0            5.483871
# 2   초기 관심 후 둔화형          15                 102.0          223.000000
# 3      초기 반응 없음          15                   0.0            0.000000
# 6       화제성 불안형           5                  50.0           47.600000
#
#    early_wilson_median  retention_median  later_reviews_median  \
# 1             0.675584          0.396104                   4.0
# 0             0.462680          2.775000                  13.5
# 4             0.858330          0.790000                 175.0
# 5             0.396773          0.200000                   1.0
# 2             0.724875          0.261905                  27.0
# 3                  NaN               NaN                   3.0
# 6             0.441032          0.320000                  13.0
#
#    post_reviews_median
# 1                 29.5
# 0                 43.5
# 4                606.5
# 5                  9.0
# 2                195.0
# 3                  9.0
# 6                 79.0

# %% [markdown]
# ## 유형별 핵심 지표 비교

# %%
plot_type_df = final_reaction_df.copy()
plot_type_df["log_early_reviews"] = np.log1p(plot_type_df["early_reviews_d0_30"])

plt.figure(figsize=(12, 6))
sns.boxplot(
    data=plot_type_df,
    x="reaction_type",
    y="log_early_reviews",
    order=order
)
plt.title("반응 유형별 초기 리뷰 수 분포")
plt.xlabel("반응 유형")
plt.ylabel("log1p(D0~30 리뷰 수)")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(
    data=final_reaction_df,
    x="reaction_type",
    y="retention_d31_180_vs_d0_30",
    order=order
)
plt.title("반응 유형별 D31~180 유지율")
plt.xlabel("반응 유형")
plt.ylabel("D31~180 / D0~30")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 추가 그래프: 반응 유형별 Wilson score 비교

# %%
# 추가 그래프 4: 반응 유형별 Wilson score 분포
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=final_reaction_df,
    x="reaction_type",
    y="early_wilson_d0_30",
    order=order
)
plt.title("반응 유형별 초기 Wilson score 분포")
plt.xlabel("반응 유형")
plt.ylabel("D0~30 Wilson score")
plt.xticks(rotation=45)
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ## 유형별 대표 게임 확인

# %%
for reaction_type in final_reaction_df["reaction_type"].value_counts().index:
    print("=" * 80)
    print(reaction_type)
    print("=" * 80)

    sample = (
        final_reaction_df[final_reaction_df["reaction_type"] == reaction_type]
        .sort_values(
            ["early_reviews_d0_30", "early_wilson_d0_30", "retention_d31_180_vs_d0_30"],
            ascending=False
        )
        .head(5)
    )

    display(
        sample[
            [
                "appid",
                "name",
                "stratum",
                "early_reviews_d0_30",
                "early_wilson_d0_30",
                "later_reviews_d31_180",
                "retention_d31_180_vs_d0_30"
            ]
        ]
    )
# Out:
# ================================================================================
# 일반형
# ================================================================================
#        appid                           name         stratum  \
# 112  2499800             Garten of Banban 6     Action_high
# 197  3453600  Supercar Collection Simulator     Racing_high
# 65   2185780           Return to abyss 重返深渊     Action_high
# 13   1173220          Bleak Faith: Forsaken        RPG_high
# 7     754890                      Firmament  Adventure_high
#
#      early_reviews_d0_30  early_wilson_d0_30  later_reviews_d31_180  \
# 112                  174            0.689894                    267
# 197                  149            0.655226                    302
# 65                   121            0.677009                    171
# 13                    99            0.664570                    152
# 7                     91            0.637492                    119
#
#      retention_d31_180_vs_d0_30
# 112                    1.534483
# 197                    2.026846
# 65                     1.413223
# 13                     1.535354
# 7                      1.307692
# ================================================================================
# 느린 입소문형
# ================================================================================
#        appid            name         stratum  early_reviews_d0_30  \
# 70   2217580    New Star™ GP     Racing_high                   28
# 167  2992500    Coin Factory    Strategy_mid                   28
# 61   2141770            URBO     Casual_high                   27
# 86   2329130   Rewind Or Die  Simulation_mid                   26
# 152  2815500  Stardust Demon      Action_mid                   24
#
#      early_wilson_d0_30  later_reviews_d31_180  retention_d31_180_vs_d0_30
# 70             0.822874                    321                   11.464286
# 167            0.644082                     79                    2.821429
# 61             0.766300                    165                    6.111111
# 86             0.758581                     60                    2.307692
# 152            0.797578                     34                    1.416667
# ================================================================================
# 초기 흥행형
# ================================================================================
#        appid                           name         stratum  \
# 29   1671210                      DELTARUNE        RPG_high
# 179  3146520                     WEBFISHING     Casual_high
# 187  3244220   A Game About Digging A Hole™  Adventure_high
# 53   1996010                   Crow Country     Action_high
# 183  3205080  Bad Parenting 1: Mr. Red Face  Adventure_high
#
#      early_reviews_d0_30  early_wilson_d0_30  later_reviews_d31_180  \
# 29                 51634            0.984045                  31247
# 179                19802            0.976055                  33823
# 187                 9956            0.896796                   4774
# 53                  2171            0.980882                   1362
# 183                 1108            0.955347                   1358
#
#      retention_d31_180_vs_d0_30
# 29                     0.605163
# 179                    1.708060
# 187                    0.479510
# 53                     0.627361
# 183                    1.225632
# ================================================================================
# 품질 위험형
# ================================================================================
#        appid                  name         stratum  early_reviews_d0_30  \
# 90   2350020            Start Over  Simulation_mid                   17
# 169  3010250        Whisper Forest  Simulation_low                   11
# 168  2993070          Candy Roller      Casual_low                   10
# 190  3274770    The Gleaming Grill      Action_low                   10
# 196  3443030  CLASS 3, THIRD GRADE   Adventure_low                   10
#
#      early_wilson_d0_30  later_reviews_d31_180  retention_d31_180_vs_d0_30
# 90             0.360051                     16                    0.941176
# 169            0.434350                      2                    0.181818
# 168            0.490157                      0                    0.000000
# 190            0.396773                      1                    0.100000
# 196            0.396773                      0                    0.000000
# ================================================================================
# 초기 관심 후 둔화형
# ================================================================================
#        appid                                        name        stratum  \
# 124  2581050                   KAMITSUBAKI CITY ENSEMBLE    Sports_high
# 5     695330              SEASON: A letter to the future    Casual_high
# 185  3215170  NEEDY STREAMER OVERLOAD: Typing of The Net    Action_high
# 126  2600600                     Internet Cafe Evolution  Strategy_high
# 31   1671720                           Athenian Rhapsody        RPG_mid
#
#      early_reviews_d0_30  early_wilson_d0_30  later_reviews_d31_180  \
# 124                  827            0.613732                    253
# 5                    683            0.914621                    210
# 185                  471            0.684132                    113
# 126                  404            0.697795                    143
# 31                   238            0.878688                     51
#
#      retention_d31_180_vs_d0_30
# 124                    0.305925
# 5                      0.307467
# 185                    0.239915
# 126                    0.353960
# 31                     0.214286
# ================================================================================
# 초기 반응 없음
# ================================================================================
#       appid                                   name       stratum  \
# 39  1789220                            Horror haze    Action_low
# 43  1818590                        You Are A Pilot    Racing_mid
# 46  1840330                            Dummy Falls    Action_mid
# 71  2235530  The Green Room Experiment (Episode 1)    Casual_low
# 74  2254670                        Dungeon Cleaner  Strategy_low
#
#     early_reviews_d0_30  early_wilson_d0_30  later_reviews_d31_180  \
# 39                    0                 NaN                      2
# 43                    0                 NaN                      0
# 46                    0                 NaN                     19
# 71                    0                 NaN                      3
# 74                    0                 NaN                      2
#
#     retention_d31_180_vs_d0_30
# 39                         NaN
# 43                         NaN
# 46                         NaN
# 71                         NaN
# 74                         NaN
# ================================================================================
# 화제성 불안형
# ================================================================================
#        appid                   name          stratum  early_reviews_d0_30  \
# 195  3389760                HoloRun       Action_mid                   60
# 159  2864860  Fallen Saint Yhoundeh          RPG_mid                   53
# 54   2015960           Parcel Corps       Racing_mid                   50
# 114  2510130         Auto Sale Life  Simulation_high                   41
# 189  3272110       Mystic Rest Stop       Casual_mid                   34
#
#      early_wilson_d0_30  later_reviews_d31_180  retention_d31_180_vs_d0_30
# 195            0.441032                     13                    0.216667
# 159            0.488067                      7                    0.132075
# 54             0.461812                     16                    0.320000
# 114            0.342542                     64                    1.560976
# 189            0.422213                     13                    0.382353

# %% [markdown]
# # 8. 보조 분석: 통계 검정과 장르 그룹 비교

# %% [markdown]
# ## 8-1. 초기 규모 높은 그룹과 낮은 그룹 비교
# 질문: 초기 리뷰 수가 높은 게임은 이후 31~180일 리뷰 수도 더 많은가?
#
# 두 그룹 비교이므로 Mann-Whitney U test를 사용

# %%
test_df = final_reaction_df[
    final_reaction_df["early_scale"].isin(["낮음", "높음"])
].dropna(subset=["later_reviews_d31_180"])

low_group = test_df[test_df["early_scale"] == "낮음"]["later_reviews_d31_180"]
high_group = test_df[test_df["early_scale"] == "높음"]["later_reviews_d31_180"]

if len(low_group) > 0 and len(high_group) > 0:
    stat, p_value = mannwhitneyu(
        high_group,
        low_group,
        alternative="two-sided"
    )

    group_test_result = pd.DataFrame({
        "comparison": ["early_scale 높음 vs 낮음"],
        "target": ["later_reviews_d31_180"],
        "low_group_n": [len(low_group)],
        "high_group_n": [len(high_group)],
        "low_group_median": [low_group.median()],
        "high_group_median": [high_group.median()],
        "u_statistic": [stat],
        "p_value": [p_value]
    })

    display(group_test_result)
else:
    print("비교 가능한 그룹 수가 부족합니다.")
# Out:
#              comparison                 target  low_group_n  high_group_n  \
# 0  early_scale 높음 vs 낮음  later_reviews_d31_180           63            63
#
#    low_group_median  high_group_median  u_statistic       p_value
# 0               4.0               69.0       3717.0  2.731000e-17

# %% [markdown]
# ## 8-2. 장르 그룹별 초기 반응 차이
#
# 질문: `stratum`에서 분리한 장르 그룹별로 초기 리뷰 수 차이가 있는가?
#
# 세 그룹 이상 비교이므로 Kruskal-Wallis test를 사용

# %%
genre_groups = []
genre_names = []

for genre, temp in final_reaction_df.groupby("genre_group"):
    values = temp["early_reviews_d0_30"].dropna()

    if len(values) >= 5:
        genre_groups.append(values)
        genre_names.append(genre)

if len(genre_groups) >= 2:
    stat, p_value = kruskal(*genre_groups)

    genre_test_result = pd.DataFrame({
        "test": ["Kruskal-Wallis"],
        "target": ["early_reviews_d0_30"],
        "group_count": [len(genre_groups)],
        "groups": [", ".join(genre_names)],
        "h_statistic": [stat],
        "p_value": [p_value]
    })

    display(genre_test_result)
else:
    print("검정 가능한 장르 그룹 수가 부족합니다.")

plt.figure(figsize=(12, 6))
sns.boxplot(
    data=final_reaction_df,
    x="genre_group",
    y=np.log1p(final_reaction_df["early_reviews_d0_30"])
)
plt.title("장르 그룹별 초기 리뷰 수 분포")
plt.xlabel("장르 그룹")
plt.ylabel("log1p(D0~30 리뷰 수)")
plt.xticks(rotation=45)
plt.show()
# Out:
#              test               target  group_count  \
# 0  Kruskal-Wallis  early_reviews_d0_30            8
#
#                                               groups  h_statistic   p_value
# 0  Action, Adventure, Casual, RPG, Racing, Simula...    10.343645  0.169921

# %% [markdown]
# ## 8-3. 주요 지표 간 Spearman 상관분석
#
#
# 여러 핵심 지표가 서로 어떤 관계를 가지는지 확인한다.\
# 리뷰 수 분포가 치우쳐 있으므로 Pearson이 아니라 Spearman 상관을 사용

# %%
corr_cols = [
    "early_reviews_d0_30",
    "early_wilson_d0_30",
    "mid_reviews_d31_90",
    "long_reviews_d91_180",
    "long_reviews_d181_plus",
    "later_reviews_d31_180",
    "post_release_reviews_total",
    "retention_d31_180_vs_d0_30"
]

corr_df = final_reaction_df[corr_cols].dropna()

corr_results = []

for i, col1 in enumerate(corr_cols):
    for col2 in corr_cols[i + 1:]:
        temp = corr_df[[col1, col2]].dropna()

        if len(temp) >= 3:
            stat, p_value = spearmanr(temp[col1], temp[col2])

            corr_results.append({
                "var1": col1,
                "var2": col2,
                "spearman_r": stat,
                "p_value": p_value,
                "n": len(temp)
            })

corr_result_df = (
    pd.DataFrame(corr_results)
    .sort_values("spearman_r", ascending=False)
)

display(corr_result_df)
# Out:
#                           var1                        var2  spearman_r  \
# 19        long_reviews_d91_180       later_reviews_d31_180    0.969216
# 15          mid_reviews_d31_90       later_reviews_d31_180    0.961211
# 23      long_reviews_d181_plus  post_release_reviews_total    0.943750
# 25       later_reviews_d31_180  post_release_reviews_total    0.943551
# 20        long_reviews_d91_180  post_release_reviews_total    0.926607
# 16          mid_reviews_d31_90  post_release_reviews_total    0.913590
# 22      long_reviews_d181_plus       later_reviews_d31_180    0.910781
# 18        long_reviews_d91_180      long_reviews_d181_plus    0.892307
# 14          mid_reviews_d31_90      long_reviews_d181_plus    0.880262
# 13          mid_reviews_d31_90        long_reviews_d91_180    0.877775
# 5          early_reviews_d0_30  post_release_reviews_total    0.841036
# 0          early_reviews_d0_30          early_wilson_d0_30    0.781729
# 4          early_reviews_d0_30       later_reviews_d31_180    0.719683
# 1          early_reviews_d0_30          mid_reviews_d31_90    0.715948
# 2          early_reviews_d0_30        long_reviews_d91_180    0.714619
# 3          early_reviews_d0_30      long_reviews_d181_plus    0.677666
# 11          early_wilson_d0_30  post_release_reviews_total    0.608042
# 26       later_reviews_d31_180  retention_d31_180_vs_d0_30    0.563129
# 17          mid_reviews_d31_90  retention_d31_180_vs_d0_30    0.520738
# 21        long_reviews_d91_180  retention_d31_180_vs_d0_30    0.519326
# 7           early_wilson_d0_30          mid_reviews_d31_90    0.518032
# 10          early_wilson_d0_30       later_reviews_d31_180    0.501239
# 8           early_wilson_d0_30        long_reviews_d91_180    0.486790
# 24      long_reviews_d181_plus  retention_d31_180_vs_d0_30    0.485901
# 9           early_wilson_d0_30      long_reviews_d181_plus    0.465748
# 27  post_release_reviews_total  retention_d31_180_vs_d0_30    0.359467
# 6          early_reviews_d0_30  retention_d31_180_vs_d0_30   -0.106722
# 12          early_wilson_d0_30  retention_d31_180_vs_d0_30   -0.150596
#
#           p_value    n
# 19  2.473980e-113  185
# 15  2.631929e-104  185
# 23   6.947647e-90  185
# 25   9.507535e-90  185
# 20   1.171946e-79  185
# 16   1.966060e-73  185
# 22   3.221533e-72  185
# 18   4.064089e-65  185
# 14   3.750064e-61  185
# 13   2.185336e-60  185
# 5    1.038180e-50  185
# 0    2.217000e-39  185
# 4    8.208273e-31  185
# 1    2.270149e-30  185
# 2    3.247764e-30  185
# 3    3.212930e-26  185
# 11   4.364203e-20  185
# 26   7.201802e-17  185
# 17   3.004780e-14  185
# 21   3.621839e-14  185
# 7    4.294916e-14  185
# 10   3.678420e-13  185
# 8    2.129854e-12  185
# 24   2.366708e-12  185
# 9    2.382679e-11  185
# 27   5.030973e-07  185
# 6    1.482133e-01  185
# 12   4.074430e-02  185

# %%
# 추가 그래프 5: 주요 지표 간 Spearman 상관 heatmap
corr_matrix = final_reaction_df[corr_cols].corr(method="spearman")

plt.figure(figsize=(10, 8))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="vlag",
    center=0
)
plt.title("주요 반응 지표 간 Spearman 상관 heatmap")
plt.show()

# %% [markdown]
# # 9. 결과 정리

# %% [markdown]
# ## 9-1. 현 분석으로 말 할 수 있는것
# - 출시 후 30일 기준 초기 반응 규모가 큰 게임을 확인할 수 있다.
# - 초기 긍정률을 Wilson score로 보정해 더 안정적으로 볼 수 있다.
# - 초기 리뷰 수와 이후 리뷰 수의 관계를 볼 수 있다.
# - 게임을 `초기 흥행형`, `느린 입소문형`, `품질 위험형` 등으로 분류할 수 있다.
# - 이 유형화는 이후 리뷰 본문 분석과 연결할 수 있다.
#
# ## 9-2. 이 노트북만으로 말하기 어려운 것
# - 왜 부정 리뷰가 나왔는지
# - 버그, 최적화, 콘텐츠 부족 등 구체적 원인
# - 패치 우선순위
# - 가격대/태그/장르의 정확한 영향
#
# > 이 부분은 `steam_indie_reviews`, `steam_indie_games`, `steam_indie_tags`와 연결해 추가 분석 필요
